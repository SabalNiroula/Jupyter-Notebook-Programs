# %%
import requests
import pandas as pd

# %%
# response is the json object we get from web
response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=df26f1996d4c98ae8b18305bb53e597d&language=en-US&page=1').json()

# %%
final = pd.DataFrame()

for j in range(1, 20):
    title= []
    vote_average= []
    release_date= []
    overview= []
    popularity= []
    vote_count= []
    original_language= []
    response = requests.get('https://api.themoviedb.org/3/movie/popular?api_key=df26f1996d4c98ae8b18305bb53e597d&language=en-US&page={}'.format(j)).json()
    for i in response['results']:
        title.append(i['title'])
        vote_average.append(i['vote_average'])
#         if (i['release_date'] in d.keys()): release_date.append(i['release_date']) 
#         else: release_date.append("Not Available")
        overview.append(i['overview'])
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])

    d={"title":title, "overview":overview,  "overview":overview, "popularity":popularity, "vote_count":vote_count, "original_language":original_language }
#     "release_date":release_date,
    df = pd.DataFrame(d)
    final = pd.concat([final, df]) #similar to final = final.append(df) but it is deprecated....
# Out:
#                                           title  \
# 0                                    Black Adam
# 1                                The Woman King
# 2                R.I.P.D. 2: Rise of the Damned
# 3                                    Cop Secret
# 4                                           Hex
# ..                                          ...
# 15                           The Desperate Hour
# 16  Princess Principal Crown Handler: Chapter 2
# 17                                         Fury
# 18                        Teenage Little Sister
# 19                                     Alienoid
#
#                                              overview  popularity  vote_count  \
# 0   Nearly 5,000 years after he was bestowed with ...    9649.909        2353
# 1   The story of the Agojie, the all-female unit o...    4957.725         564
# 2   When Sheriff Roy Pulsipher finds himself in th...    2981.316         194
# ...

# %%
final
# Out:
#                                           title  \
# 0                                    Black Adam
# 1                                The Woman King
# 2                R.I.P.D. 2: Rise of the Damned
# 3                                    Cop Secret
# 4                                           Hex
# ..                                          ...
# 15                           The Desperate Hour
# 16  Princess Principal Crown Handler: Chapter 2
# 17                                         Fury
# 18                        Teenage Little Sister
# 19                                     Alienoid
#
#                                              overview  popularity  vote_count  \
# 0   Nearly 5,000 years after he was bestowed with ...    9649.909        2353
# 1   The story of the Agojie, the all-female unit o...    4957.725         564
# 2   When Sheriff Roy Pulsipher finds himself in th...    2981.316         194
# ...
